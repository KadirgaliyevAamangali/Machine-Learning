# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read in the document-term matrix
import pandas as pd

data = pd.read_pickle('//content/drive/MyDrive/project_pop/clean_data_dtm.pkl')          
data = data.transpose()
data
# Out:
#           Madonna  Michael Jackson  Rihanna  Taylor Swift  The Beatles
# abnormal        1                0        0             0            0
# about           2               19        3            10            2
# across          0                3        0             0            1
# act             1                0        2             0            0
# action          0                0        1             0            0
# ...           ...              ...      ...           ...          ...
# yours           0                1        0             4            0
# yourself        4               10        0             0            0
# youve           3                5        3             1            2
# yuh             0                0        1             0            0
# él              1                0        0             0            0
#
# [1532 rows x 5 columns]

# %%
# Find the top 30 words said by each pop artist
top_dict = {}
for c in data.columns:
    top = data[c].sort_values(ascending=False).head(30)
    top_dict[c]= list(zip(top.index, top.values))

top_dict
# Out:
# {'Madonna': [('you', 141),
#   ('up', 130),
#   ('be', 115),
#   ('it', 96),
#   ('the', 89),
#   ('to', 83),
#   ('your', 76),
#   ('and', 67),
#   ('wake', 64),
#   ('me', 56),
#   ('in', 51),
#   ('my', 46),
#   ('so', 45),
#   ('we', 43),
#   ('get', 42),
#   ('world', 37),
#   ('material', 36),
#   ('that', 36),
#   ('four', 34),
#   ('can', 34),
#   ('go', 33),
#   ('there', 30),
#   ('vogue', 30),
#   ('take', 28),
#   ('wait', 27),
#   ('slowly', 27),
#   ('prayer', 26),
#   ('all', 25),
#   ('of', 24),
#   ('what', 24)],
#  'Michael Jackson': [('you', 215),
#   ('be', 192),
#   ('the', 161),
#   ('it', 116),
#   ('why', 101),
#   ('bad', 94),
#   ('to', 79),
#   ('me', 77),
#   ('that', 77),
#   ('beat', 66),
#   ('no', 62),
#   ('really', 61),
#   ('and', 57),
#   ('okay', 50),
#   ('annie', 48),
#   ('your', 43),
#   ('diana', 40),
#   ('they', 38),
#   ('in', 38),
#   ('my', 36),
#   ('dirty', 36),
#   ('do', 34),
#   ('thriller', 33),
#   ('she', 33),
#   ('who', 30),
# ...

# %%
top_dict_df = pd.DataFrame.from_records(top_dict)
#top_dict_df.columns = ['words']
top_dict_df = top_dict_df.sort_index()

top_dict_df

# pickle collected dataset for later use
#raw_data_df.to_pickle("raw_data_df.pkl")
# Out:
#            Madonna Michael Jackson        Rihanna Taylor Swift     The Beatles
# 0       (you, 141)      (you, 215)     (you, 147)   (you, 252)       (be, 112)
# 1        (up, 130)       (be, 192)      (it, 121)    (be, 153)       (the, 89)
# 2        (be, 115)      (the, 161)      (me, 120)   (the, 129)        (it, 83)
# 3         (it, 96)       (it, 116)      (the, 86)    (me, 113)       (let, 52)
# 4        (the, 89)      (why, 101)       (to, 85)   (and, 108)        (to, 49)
# 5         (to, 83)       (bad, 94)     (work, 79)     (it, 76)      (come, 44)
# 6       (your, 76)        (to, 79)       (be, 74)   (your, 71)      (jude, 42)
# 7        (and, 67)        (me, 77)       (do, 54)     (my, 65)       (you, 41)
# 8       (wake, 64)      (that, 77)      (and, 53)     (in, 56)       (and, 37)
# 9         (me, 56)      (beat, 66)       (in, 51)     (to, 55)        (me, 35)
# 10        (in, 51)        (no, 62)       (my, 47)   (what, 51)        (in, 32)
# ...

# %%
import matplotlib.pyplot as plt

# %%
for k in top_dict.keys():
    keys = []
    values = []
    i = 0
    while i < len(top_dict[k]):
        keys.append((top_dict[k][i][0]))
        values.append((top_dict[k][i][1]))
        i+=1
    plt.figure(figsize=(30,15))
    plt.title(k, fontsize=24)
    plt.xlabel('words', fontsize=24)
    plt.ylabel('frequency', fontsize=24)
    plt.bar(keys, values)
print(plt.show())
# Out:
# None

# %%
# Look at the most common top words --> add them to the stop word list
from collections import Counter

# Let's first pull out the top 30 words for each comedian
words = []
for pop in data.columns:
    top = [word for (word, count) in top_dict[pop]]
    for t in top:
        words.append(t)
        
words
# Out:
# ['you',
#  'up',
#  'be',
#  'it',
#  'the',
#  'to',
#  'your',
#  'and',
#  'wake',
#  'me',
#  'in',
#  'my',
#  'so',
#  'we',
#  'get',
#  'world',
#  'material',
#  'that',
#  'four',
#  'can',
#  'go',
#  'there',
#  'vogue',
#  'take',
#  'wait',
#  'slowly',
#  'prayer',
#  'all',
#  'of',
#  'what',
#  'you',
#  'be',
#  'the',
#  'it',
#  'why',
#  'bad',
#  'to',
#  'me',
#  'that',
#  'beat',
#  'no',
#  'really',
#  'and',
#  'okay',
#  'annie',
#  'your',
#  'diana',
#  'they',
#  'in',
#  'my',
#  'dirty',
#  'do',
#  'thriller',
#  'she',
#  'who',
#  'of',
#  'wan',
#  'not',
#  'he',
#  'way',
#  'you',
#  'it',
#  'me',
#  'the',
#  'to',
#  'work',
#  'be',
#  'do',
#  'and',
#  'in',
#  'my',
#  'get',
#  'diamond',
#  'oh',
#  'that',
#  'when',
#  'what',
#  'take',
#  'shine',
#  'baby',
#  'love',
#  'bright',
#  'no',
#  'dirt',
#  'ella',
#  'kiss',
#  'need',
#  'now',
#  'learn',
#  'tell',
#  'you',
#  'be',
#  'the',
#  'me',
#  'and',
#  'it',
# ...

# %%
# Let's aggregate this list and identify the most common words along with how many routines they occur in
Counter(words).most_common()
# Out:
# [('you', 5),
#  ('be', 5),
#  ('it', 5),
#  ('the', 5),
#  ('to', 5),
#  ('and', 5),
#  ('me', 5),
#  ('in', 5),
#  ('my', 4),
#  ('get', 4),
#  ('of', 4),
#  ('your', 3),
#  ('that', 3),
#  ('all', 3),
#  ('what', 3),
#  ('do', 3),
#  ('so', 2),
#  ('we', 2),
#  ('can', 2),
#  ('take', 2),
#  ('no', 2),
#  ('they', 2),
#  ('wan', 2),
#  ('he', 2),
#  ('way', 2),
#  ('when', 2),
#  ('now', 2),
#  ('for', 2),
#  ('up', 1),
#  ('wake', 1),
#  ('world', 1),
#  ('material', 1),
#  ('four', 1),
#  ('go', 1),
#  ('there', 1),
#  ('vogue', 1),
#  ('wait', 1),
#  ('slowly', 1),
#  ('prayer', 1),
#  ('why', 1),
#  ('bad', 1),
#  ('beat', 1),
#  ('really', 1),
#  ('okay', 1),
#  ('annie', 1),
#  ('diana', 1),
#  ('dirty', 1),
#  ('thriller', 1),
#  ('she', 1),
#  ('who', 1),
#  ('not', 1),
#  ('work', 1),
#  ('diamond', 1),
#  ('oh', 1),
#  ('shine', 1),
#  ('baby', 1),
#  ('love', 1),
#  ('bright', 1),
#  ('dirt', 1),
#  ('ella', 1),
#  ('kiss', 1),
#  ('need', 1),
#  ('learn', 1),
# ...

# %%
# If more than half of the pops have it as a top word, exclude it from the list
add_stop_words = [word for word, count in Counter(words).most_common() if count > 0]
add_stop_words
# Out:
# ['you',
#  'be',
#  'it',
#  'the',
#  'to',
#  'and',
#  'me',
#  'in',
#  'my',
#  'get',
#  'of',
#  'your',
#  'that',
#  'all',
#  'what',
#  'do',
#  'so',
#  'we',
#  'can',
#  'take',
#  'no',
#  'they',
#  'wan',
#  'he',
#  'way',
#  'when',
#  'now',
#  'for',
#  'up',
#  'wake',
#  'world',
#  'material',
#  'four',
#  'go',
#  'there',
#  'vogue',
#  'wait',
#  'slowly',
#  'prayer',
#  'why',
#  'bad',
#  'beat',
#  'really',
#  'okay',
#  'annie',
#  'diana',
#  'dirty',
#  'thriller',
#  'she',
#  'who',
#  'not',
#  'work',
#  'diamond',
#  'oh',
#  'shine',
#  'baby',
#  'love',
#  'bright',
#  'dirt',
#  'ella',
#  'kiss',
#  'need',
#  'learn',
#  'tell',
#  'but',
#  'look',
#  'never',
#  'end',
#  'this',
#  'game',
#  'see',
#  'if',
#  'out',
#  'let',
#  'come',
#  'jude',
#  'sun',
#  'hey',
#  'here',
#  'shoot',
#  'joob',
#  'people',
#  'well',
#  'goo',
#  'lonely',
#  'have',
#  'together']

# %%
data
# Out:
#           Madonna  Michael Jackson  Rihanna  Taylor Swift  The Beatles
# abnormal        1                0        0             0            0
# about           2               19        3            10            2
# across          0                3        0             0            1
# act             1                0        2             0            0
# action          0                0        1             0            0
# ...           ...              ...      ...           ...          ...
# yours           0                1        0             4            0
# yourself        4               10        0             0            0
# youve           3                5        3             1            2
# yuh             0                0        1             0            0
# él              1                0        0             0            0
#
# [1532 rows x 5 columns]

# %%
data = data.transpose()

# %%
for w in add_stop_words:
    del data[w]

# %%
data
# Out:
#                  abnormal  about  across  act  ...  yourself  youve  yuh  él
# Madonna                 1      2       0    1  ...         4      3    0   1
# Michael Jackson         0     19       3    0  ...        10      5    0   0
# Rihanna                 0      3       0    2  ...         0      3    1   0
# Taylor Swift            0     10       0    0  ...         0      1    0   0
# The Beatles             0      2       1    0  ...         0      2    0   0
#
# [5 rows x 1445 columns]

# %%
# Pickle it for later use
import pickle
data.to_pickle("/content/drive/MyDrive/project_pop/data_cleaned_sw.pkl")

# %%
add_stop_words_2 = add_stop_words.append('im')

# %%
# Let's make some word clouds!
from wordcloud import WordCloud

wc = WordCloud(stopwords=add_stop_words_2, background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42, width=1200, height=1200)

# %%
print(add_stop_words_2)
# Out:
# None

# %%
# Read in cleaned data
#data_clean = pd.read_pickle('data_clean.pkl')
data_clean = pd.read_pickle('/content/drive/MyDrive/project_pop/data_clean_df.pkl')

# %%
# Reset the output dimensions
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [50, 50]

# my final list of pop artists whose album will be analysed
pops = ['Madonna', 'Micheal Jackson', 'Rihanna', 'Taylor Swift', 'The Beatles']

# Create subplots for each comedian
for index, pop in enumerate(data.transpose().columns):
    wc.generate(data_clean.lyrics[pop])
    
    plt.subplot(3, 4, index+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(pops[index], fontsize=30)
    
plt.show()
